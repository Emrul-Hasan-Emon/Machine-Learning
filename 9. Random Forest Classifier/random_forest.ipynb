# %%
import pandas as pd
from sklearn.datasets import load_digits

# %% [markdown]
# # 1. Collect Dataset - Digits Dataset from sklearn library

# %%
digits = load_digits()

# %%
dir(digits)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.gray() 
for i in range(4):
    plt.matshow(digits.images[i])

# %% [markdown]
# # 2. Data Preparation

# %%
df = pd.DataFrame(digits.data)
df.head()

# %%
f = pd.DataFrame(digits.data)
df.head()

# %%
df['target'] = digits.target

# %%
df[0:12]

# %%
X = df.drop('target', axis = 'columns') # Drop the target column to get feature data.
y = df.target # Prediction target is stored in target column.

# %% [markdown]
# ## Split the dataset into Training & Testing dataset

# %% [markdown]
# from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # 3. Train the model

# %% [markdown]
# from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators = 20)
model.fit(X_train, y_train)

# %% [markdown]
# # 4. Predict the model

# %% [markdown]
# model.score(X_test, y_test)

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_predicted)
# cm

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot = True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

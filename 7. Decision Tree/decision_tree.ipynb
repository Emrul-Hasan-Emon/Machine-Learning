# %%
import pandas as pd

# %% [markdown]
# # 1. Collect Dataset - Salaries Dataset

# %%
df = pd.read_csv("salaries.csv")
df.head()

# %% [markdown]
# # 2. Preparing Dataset
# ## Drop the predicted column

# %%
inputs = df.drop('salary_more_then_100k', axis = 'columns') # Drop the entire column

# %%
target = df['salary_more_then_100k']

# %%
from sklearn.preprocessing import LabelEncoderle_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %% [markdown]
# ## Use One Hot Encoding mechanism to convert the text columns into numbers

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %% [markdown]
# ## Drop the text columns as the those were converted into numbers

# %% [markdown]
# inputs_n = inputs.drop(['company','job','degree'],axis='columns')

# %%
inputs_n

# %%
target

# %% [markdown]
# # 3. Decision Tree - Import & Train the model

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)

# %% [markdown]
# ## Find Accuracy

# %% [markdown]
# model.score(inputs_n,target)
